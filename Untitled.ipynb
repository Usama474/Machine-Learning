# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
d = load_iris()
dir(d)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
X=df= pd.DataFrame(d.data, columns = d.feature_names)

# %%
df['target']= d.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
Y= df.target
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
model = RandomForestClassifier(n_estimators= 40)

# %%
X= df.drop(['target'], axis= 'columns')
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X,Y, test_size=0.2)
xtest
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 141                6.9               3.1                5.1               2.3
# 3                  4.6               3.1                1.5               0.2
# 17                 5.1               3.5                1.4               0.3
# 62                 6.0               2.2                4.0               1.0
# 42                 4.4               3.2                1.3               0.2
# 149                5.9               3.0                5.1               1.8
# 77                 6.7               3.0                5.0               1.7
# 53                 5.5               2.3                4.0               1.3
# 64                 5.6               2.9                3.6               1.3
# 142                5.8               2.7                5.1               1.9
# 60                 5.0               2.0                3.5               1.0
# 23                 5.1               3.3                1.7               0.5
# 18                 5.7               3.8                1.7               0.3
# 72                 6.3               2.5                4.9               1.5
# 140                6.7               3.1                5.6               2.4
# 122                7.7               2.8                6.7               2.0
# 55                 5.7               2.8                4.5               1.3
# 65                 6.7               3.1                4.4               1.4
# 82                 5.8               2.7                3.9               1.2
# 12                 4.8               3.0                1.4               0.1
# 114                5.8               2.8                5.1               2.4
# 81                 5.5               2.4                3.7               1.0
# 108                6.7               2.5                5.8               1.8
# 125                7.2               3.2                6.0               1.8
# 11                 4.8               3.4                1.6               0.2
# 25                 5.0               3.0                1.6               0.2
# 61                 5.9               3.0                4.2               1.5
# 144                6.7               3.3                5.7               2.5
# 19                 5.1               3.8                1.5               0.3
# 49                 5.0               3.3                1.4               0.2

# %%
model = RandomForestClassifier(n_estimators= 50)
model.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
model.predict(xtest)
# Out:
# array([0, 0, 0, 0, 0, 2, 1, 1, 2, 1, 1, 1, 2, 1, 1, 2, 2, 0, 2, 2, 0, 1,
#        0, 0, 2, 0, 1, 2, 1, 0])

# %%
model.score(xtest,ytest)
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(model.predict(xtest), ytest)
cm
# Out:
# array([[11,  0,  0],
#        [ 0,  9,  1],
#        [ 0,  1,  8]], dtype=int64)

# %%
plt.figure(figsize= (10, 7))
sn.heatmap(cm, annot= True)

plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(69.0, 0.5, 'Truth')
